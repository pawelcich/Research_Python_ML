# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
np.random.normal(0, 1, (2,5))
# Out:
# array([[-1.82807027,  2.2746579 ,  1.15663669,  0.74308661,  0.63226201],
#        [-1.19452017,  1.70029461, -0.58919288, -0.44407418, -0.320724  ]])

# %%
delta_X = np.random.normal(0, 1, (2,5))
print(delta_X[0])
print(delta_X[1])
# Out:
# [ 0.72052966 -1.11486491 -1.49764459 -0.41987391  1.14478167]
# [-0.48710298  2.74473366 -0.63984975 -0.2404264   1.32710379]

# %%
plt.plot(delta_X[0], delta_X[1], "go")

# %%
print(delta_X)
X = np.cumsum(delta_X, axis=1)
X
# Out:
# [[ 0.72052966 -1.11486491 -1.49764459 -0.41987391  1.14478167]
#  [-0.48710298  2.74473366 -0.63984975 -0.2404264   1.32710379]]
# array([[ 0.72052966, -0.39433525, -1.89197984, -2.31185375, -1.16707208],
#        [-0.48710298,  2.25763068,  1.61778092,  1.37735452,  2.70445831]])

# %%
X_0 = np.array([[0],[0]])

# %%
delta_X = np.random.normal(0,1,(2,10000))
X = np.cumsum(delta_X, axis=1)
plt.plot(X[0],X[1], "ro-")
#plt.savefig("rw.pdf")

# %%
# Adding 0,0 coordinate to start from
X = np.concatenate((X_0, X), axis=1)

# %%
plt.plot(X[0],X[1], "ro-")
#plt.savefig("rw3_100.pdf")
